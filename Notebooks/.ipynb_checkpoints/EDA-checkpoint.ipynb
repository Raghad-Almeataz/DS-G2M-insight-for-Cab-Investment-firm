# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import datetime

# %%
cab=pd.read_csv('../data/Cab_Data.csv')
cab
# Out:
#         Transaction ID Date of Travel     Company           City  \
# 0             10000011     2016-01-08    Pink Cab     ATLANTA GA
# 1             10000012     2016-01-06    Pink Cab     ATLANTA GA
# 2             10000013     2016-01-02    Pink Cab     ATLANTA GA
# 3             10000014     2016-01-07    Pink Cab     ATLANTA GA
# 4             10000015     2016-01-03    Pink Cab     ATLANTA GA
# ...                ...            ...         ...            ...
# 359387        10440101     2018-01-08  Yellow Cab  WASHINGTON DC
# 359388        10440104     2018-01-04  Yellow Cab  WASHINGTON DC
# 359389        10440105     2018-01-05  Yellow Cab  WASHINGTON DC
# 359390        10440106     2018-01-05  Yellow Cab  WASHINGTON DC
# 359391        10440107     2018-01-02  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip
# 0              30.45         370.95      313.6350
# 1              28.62         358.52      334.8540
# 2               9.04         125.20       97.6320
# 3              33.17         377.40      351.6020
# 4               8.73         114.62       97.7760
# ...              ...            ...           ...
# 359387          4.80          69.24       63.3600
# 359388          8.40         113.75      106.8480
# 359389         27.75         437.07      349.6500
# 359390          8.80         146.19      114.0480
# 359391         12.76         191.58      177.6192
#
# [359392 rows x 7 columns]

# %%
city=pd.read_csv('../data/City.csv')
city
# Out:
#                 City   Population      Users
# 0        NEW YORK NY   8,405,837    302,149
# 1         CHICAGO IL   1,955,130    164,468
# 2     LOS ANGELES CA   1,595,037    144,132
# 3           MIAMI FL   1,339,155     17,675
# 4     SILICON VALLEY   1,177,609     27,247
# 5      ORANGE COUNTY   1,030,185     12,994
# 6       SAN DIEGO CA     959,307     69,995
# 7         PHOENIX AZ     943,999      6,133
# 8          DALLAS TX     942,908     22,157
# 9         ATLANTA GA     814,885     24,701
# 10         DENVER CO     754,233     12,421
# 11         AUSTIN TX     698,371     14,978
# 12        SEATTLE WA     671,238     25,063
# 13         TUCSON AZ     631,442      5,712
# 14  SAN FRANCISCO CA     629,591    213,609
# 15     SACRAMENTO CA     545,776      7,044
# 16     PITTSBURGH PA     542,085      3,643
# 17     WASHINGTON DC     418,859    127,001
# 18      NASHVILLE TN     327,225      9,270
# 19         BOSTON MA     248,968     80,021

# %%
cust=pd.read_csv('../data/Customer_ID.csv')
cust
# Out:
#        Customer ID  Gender  Age  Income (USD/Month)
# 0            29290    Male   28               10813
# 1            27703    Male   27                9237
# 2            28712    Male   53               11242
# 3            28020    Male   23               23327
# 4            27182    Male   33                8536
# ...            ...     ...  ...                 ...
# 49166        12490    Male   33               18713
# 49167        14971    Male   30               15346
# 49168        41414    Male   38                3960
# 49169        41677    Male   23               19454
# 49170        39761  Female   32               10128
#
# [49171 rows x 4 columns]

# %%
trans=pd.read_csv('../data/Transaction_ID.csv')
trans
# Out:
#         Transaction ID  Customer ID Payment_Mode
# 0             10000011        29290         Card
# 1             10000012        27703         Card
# 2             10000013        28712         Cash
# 3             10000014        28020         Cash
# 4             10000015        27182         Card
# ...                ...          ...          ...
# 440093        10440104        53286         Cash
# 440094        10440105        52265         Cash
# 440095        10440106        52175         Card
# 440096        10440107        52917         Card
# 440097        10440108        51587         Card
#
# [440098 rows x 3 columns]

# %%
df1=pd.merge(cab, city, on='City')
df1
# Out:
#         Transaction ID Date of Travel     Company           City  \
# 0             10000011     2016-01-08    Pink Cab     ATLANTA GA
# 1             10000012     2016-01-06    Pink Cab     ATLANTA GA
# 2             10000013     2016-01-02    Pink Cab     ATLANTA GA
# 3             10000014     2016-01-07    Pink Cab     ATLANTA GA
# 4             10000015     2016-01-03    Pink Cab     ATLANTA GA
# ...                ...            ...         ...            ...
# 359387        10440101     2018-01-08  Yellow Cab  WASHINGTON DC
# 359388        10440104     2018-01-04  Yellow Cab  WASHINGTON DC
# 359389        10440105     2018-01-05  Yellow Cab  WASHINGTON DC
# 359390        10440106     2018-01-05  Yellow Cab  WASHINGTON DC
# 359391        10440107     2018-01-02  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip Population      Users
# 0              30.45         370.95      313.6350   814,885     24,701
# 1              28.62         358.52      334.8540   814,885     24,701
# 2               9.04         125.20       97.6320   814,885     24,701
# 3              33.17         377.40      351.6020   814,885     24,701
# 4               8.73         114.62       97.7760   814,885     24,701
# ...              ...            ...           ...        ...        ...
# 359387          4.80          69.24       63.3600   418,859    127,001
# 359388          8.40         113.75      106.8480   418,859    127,001
# 359389         27.75         437.07      349.6500   418,859    127,001
# 359390          8.80         146.19      114.0480   418,859    127,001
# 359391         12.76         191.58      177.6192   418,859    127,001
#
# [359392 rows x 9 columns]

# %%
df2=pd.merge(df1, trans, on='Transaction ID')
df2
# Out:
#         Transaction ID Date of Travel     Company           City  \
# 0             10000011     2016-01-08    Pink Cab     ATLANTA GA
# 1             10000012     2016-01-06    Pink Cab     ATLANTA GA
# 2             10000013     2016-01-02    Pink Cab     ATLANTA GA
# 3             10000014     2016-01-07    Pink Cab     ATLANTA GA
# 4             10000015     2016-01-03    Pink Cab     ATLANTA GA
# ...                ...            ...         ...            ...
# 359387        10440101     2018-01-08  Yellow Cab  WASHINGTON DC
# 359388        10440104     2018-01-04  Yellow Cab  WASHINGTON DC
# 359389        10440105     2018-01-05  Yellow Cab  WASHINGTON DC
# 359390        10440106     2018-01-05  Yellow Cab  WASHINGTON DC
# 359391        10440107     2018-01-02  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip Population      Users  \
# 0              30.45         370.95      313.6350   814,885     24,701
# 1              28.62         358.52      334.8540   814,885     24,701
# 2               9.04         125.20       97.6320   814,885     24,701
# 3              33.17         377.40      351.6020   814,885     24,701
# 4               8.73         114.62       97.7760   814,885     24,701
# ...              ...            ...           ...        ...        ...
# 359387          4.80          69.24       63.3600   418,859    127,001
# 359388          8.40         113.75      106.8480   418,859    127,001
# 359389         27.75         437.07      349.6500   418,859    127,001
# 359390          8.80         146.19      114.0480   418,859    127,001
# 359391         12.76         191.58      177.6192   418,859    127,001
#
#         Customer ID Payment_Mode
# 0             29290         Card
# 1             27703         Card
# 2             28712         Cash
# 3             28020         Cash
# 4             27182         Card
# ...             ...          ...
# 359387        52392         Cash
# 359388        53286         Cash
# 359389        52265         Cash
# 359390        52175         Card
# 359391        52917         Card
#
# [359392 rows x 11 columns]

# %%
df=pd.merge(df2, cust, on='Customer ID')
df
# Out:
#         Transaction ID Date of Travel     Company           City  \
# 0             10000011     2016-01-08    Pink Cab     ATLANTA GA
# 1             10351127     2018-07-21  Yellow Cab     ATLANTA GA
# 2             10412921     2018-11-23  Yellow Cab     ATLANTA GA
# 3             10000012     2016-01-06    Pink Cab     ATLANTA GA
# 4             10320494     2018-04-21  Yellow Cab     ATLANTA GA
# ...                ...            ...         ...            ...
# 359387        10307228     2018-03-03  Yellow Cab  WASHINGTON DC
# 359388        10319775     2018-04-13  Yellow Cab  WASHINGTON DC
# 359389        10347676     2018-07-06  Yellow Cab  WASHINGTON DC
# 359390        10358624     2018-08-02  Yellow Cab  WASHINGTON DC
# 359391        10370709     2018-08-30  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip Population      Users  \
# 0              30.45         370.95      313.6350   814,885     24,701
# 1              26.19         598.70      317.4228   814,885     24,701
# 2              42.55         792.05      597.4020   814,885     24,701
# 3              28.62         358.52      334.8540   814,885     24,701
# 4              36.38         721.10      467.1192   814,885     24,701
# ...              ...            ...           ...        ...        ...
# 359387         38.40         668.93      525.3120   418,859    127,001
# 359388          3.57          67.60       44.5536   418,859    127,001
# 359389         23.46         331.97      337.8240   418,859    127,001
# 359390         27.60         358.23      364.3200   418,859    127,001
# 359391         34.24         453.11      427.3152   418,859    127,001
#
#         Customer ID Payment_Mode  Gender  Age  Income (USD/Month)
# 0             29290         Card    Male   28               10813
# 1             29290         Cash    Male   28               10813
# 2             29290         Card    Male   28               10813
# 3             27703         Card    Male   27                9237
# 4             27703         Card    Male   27                9237
# ...             ...          ...     ...  ...                 ...
# 359387        51406         Cash  Female   29                6829
# 359388        51406         Cash  Female   29                6829
# 359389        51406         Card  Female   29                6829
# 359390        51406         Cash  Female   29                6829
# 359391        51406         Card  Female   29                6829
#
# [359392 rows x 14 columns]

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
df['Users']=df['Users'].str.replace(',',"").astype(int)
df['Population']=df['Population'].str.replace(',',"").astype(int)

# %%
df['Date of Travel']=pd.to_datetime(df['Date of Travel'])

# %%
df['Day'] = df['Date of Travel'].dt.day
df['Month'] = df['Date of Travel'].dt.month
df['Year'] = df['Date of Travel'].dt.year
# Out:
#    Transaction ID Date of Travel     Company        City  KM Travelled  \
# 0        10000011     2016-01-08    Pink Cab  ATLANTA GA         30.45
# 1        10351127     2018-07-21  Yellow Cab  ATLANTA GA         26.19
# 2        10412921     2018-11-23  Yellow Cab  ATLANTA GA         42.55
# 3        10000012     2016-01-06    Pink Cab  ATLANTA GA         28.62
# 4        10320494     2018-04-21  Yellow Cab  ATLANTA GA         36.38
#
#    Price Charged  Cost of Trip  Population  Users  Customer ID Payment_Mode  \
# 0         370.95      313.6350      814885  24701        29290         Card
# 1         598.70      317.4228      814885  24701        29290         Cash
# 2         792.05      597.4020      814885  24701        29290         Card
# 3         358.52      334.8540      814885  24701        27703         Card
# 4         721.10      467.1192      814885  24701        27703         Card
#
#   Gender  Age  Income (USD/Month)  Day  Month  Year
# 0   Male   28               10813    8      1  2016
# 1   Male   28               10813   21      7  2018
# 2   Male   28               10813   23     11  2018
# 3   Male   27                9237    6      1  2016
# 4   Male   27                9237   21      4  2018

# %%
df['Profit']=df['Price Charged']-df['Cost of Trip']

# %%
df.dtypes
# Out:
# Transaction ID                 int64
# Date of Travel        datetime64[ns]
# Company                       object
# City                          object
# KM Travelled                 float64
# Price Charged                float64
# Cost of Trip                 float64
# Population                     int32
# Users                          int32
# Customer ID                    int64
# Payment_Mode                  object
# Gender                        object
# Age                            int64
# Income (USD/Month)             int64
# Day                            int64
# Month                          int64
# Year                           int64
# Profit                       float64
# dtype: object

# %%
df.columns
# Out:
# ['Transaction ID',
#  'Date of Travel',
#  'Company',
#  'City',
#  'KM Travelled',
#  'Price Charged',
#  'Cost of Trip',
#  'Population',
#  'Users',
#  'Customer ID',
#  'Payment_Mode',
#  'Gender',
#  'Age',
#  'Income (USD/Month)',
#  'Day',
#  'Month',
#  'Year',
#  'Profit']

# %%
reindex=['Transaction ID',
         'Customer ID',
         'Date of Travel',
         'Day',
         'Month',
         'Year',
         'Company',
         'City',
         'KM Travelled',
         'Price Charged',
         'Cost of Trip',
         'Profit',
         'Population',
         'Users',
         'Payment_Mode',
         'Gender',
         'Age',
         'Income (USD/Month)',
]
df=df.reindex(columns=reindex)

# %%
df.describe()
# Out:
#        Transaction ID   KM Travelled  Price Charged   Cost of Trip  \
# count    3.593920e+05  359392.000000  359392.000000  359392.000000
# mean     1.022076e+07      22.567254     423.443311     286.190113
# std      1.268058e+05      12.233526     274.378911     157.993661
# min      1.000001e+07       1.900000      15.600000      19.000000
# 25%      1.011081e+07      12.000000     206.437500     151.200000
# 50%      1.022104e+07      22.440000     386.360000     282.480000
# 75%      1.033094e+07      32.960000     583.660000     413.683200
# max      1.044011e+07      48.000000    2048.030000     691.200000
#
#          Population          Users    Customer ID            Age  \
# count  3.593920e+05  359392.000000  359392.000000  359392.000000
# mean   3.132198e+06  158365.582267   19191.652115      35.336705
# std    3.315194e+06  100850.051020   21012.412463      12.594234
# min    2.489680e+05    3643.000000       1.000000      18.000000
# 25%    6.712380e+05   80021.000000    2705.000000      25.000000
# 50%    1.595037e+06  144132.000000    7459.000000      33.000000
# 75%    8.405837e+06  302149.000000   36078.000000      42.000000
# max    8.405837e+06  302149.000000   60000.000000      65.000000
#
#        Income (USD/Month)
# count       359392.000000
# mean         15048.822937
# std           7969.409482
# min           2000.000000
# 25%           8424.000000
# 50%          14685.000000
# 75%          21035.000000
# max          35000.000000

# %%
df.describe(exclude='number')
# Out:
#        Date of Travel     Company         City Payment_Mode  Gender
# count          359392      359392       359392       359392  359392
# unique           1095           2           19            2       2
# top        2018-01-05  Yellow Cab  NEW YORK NY         Card    Male
# freq             2022      274681        99885       215504  205912

# %%
df
# Out:
#         Transaction ID  Customer ID Date of Travel  Day  Month  Year  \
# 0             10000011        29290     2016-01-08    8      1  2016
# 1             10351127        29290     2018-07-21   21      7  2018
# 2             10412921        29290     2018-11-23   23     11  2018
# 3             10000012        27703     2016-01-06    6      1  2016
# 4             10320494        27703     2018-04-21   21      4  2018
# ...                ...          ...            ...  ...    ...   ...
# 359387        10307228        51406     2018-03-03    3      3  2018
# 359388        10319775        51406     2018-04-13   13      4  2018
# 359389        10347676        51406     2018-07-06    6      7  2018
# 359390        10358624        51406     2018-08-02    2      8  2018
# 359391        10370709        51406     2018-08-30   30      8  2018
#
#            Company           City  KM Travelled  Price Charged  Cost of Trip  \
# 0         Pink Cab     ATLANTA GA         30.45         370.95      313.6350
# 1       Yellow Cab     ATLANTA GA         26.19         598.70      317.4228
# 2       Yellow Cab     ATLANTA GA         42.55         792.05      597.4020
# 3         Pink Cab     ATLANTA GA         28.62         358.52      334.8540
# 4       Yellow Cab     ATLANTA GA         36.38         721.10      467.1192
# ...            ...            ...           ...            ...           ...
# 359387  Yellow Cab  WASHINGTON DC         38.40         668.93      525.3120
# 359388  Yellow Cab  WASHINGTON DC          3.57          67.60       44.5536
# 359389  Yellow Cab  WASHINGTON DC         23.46         331.97      337.8240
# 359390  Yellow Cab  WASHINGTON DC         27.60         358.23      364.3200
# 359391  Yellow Cab  WASHINGTON DC         34.24         453.11      427.3152
#
#           Profit  Population   Users Payment_Mode  Gender  Age  \
# 0        57.3150      814885   24701         Card    Male   28
# 1       281.2772      814885   24701         Cash    Male   28
# 2       194.6480      814885   24701         Card    Male   28
# 3        23.6660      814885   24701         Card    Male   27
# 4       253.9808      814885   24701         Card    Male   27
# ...          ...         ...     ...          ...     ...  ...
# 359387  143.6180      418859  127001         Cash  Female   29
# 359388   23.0464      418859  127001         Cash  Female   29
# 359389   -5.8540      418859  127001         Card  Female   29
# 359390   -6.0900      418859  127001         Cash  Female   29
# 359391   25.7948      418859  127001         Card  Female   29
#
#         Income (USD/Month)
# 0                    10813
# 1                    10813
# 2                    10813
# 3                     9237
# 4                     9237
# ...                    ...
# 359387                6829
# 359388                6829
# 359389                6829
# 359390                6829
# 359391                6829
#
# [359392 rows x 18 columns]

# %%
ydf=df[df['Company']=='Yellow Cab']
ydf
# Out:
#         Transaction ID  Customer ID Date of Travel  Day  Month  Year  \
# 1             10351127        29290     2018-07-21   21      7  2018
# 2             10412921        29290     2018-11-23   23     11  2018
# 4             10320494        27703     2018-04-21   21      4  2018
# 5             10324737        27703     2018-05-04    4      5  2018
# 8             10079404        28712     2016-09-21   21      9  2016
# ...                ...          ...            ...  ...    ...   ...
# 359387        10307228        51406     2018-03-03    3      3  2018
# 359388        10319775        51406     2018-04-13   13      4  2018
# 359389        10347676        51406     2018-07-06    6      7  2018
# 359390        10358624        51406     2018-08-02    2      8  2018
# 359391        10370709        51406     2018-08-30   30      8  2018
#
#            Company           City  KM Travelled  Price Charged  Cost of Trip  \
# 1       Yellow Cab     ATLANTA GA         26.19         598.70      317.4228
# 2       Yellow Cab     ATLANTA GA         42.55         792.05      597.4020
# 4       Yellow Cab     ATLANTA GA         36.38         721.10      467.1192
# 5       Yellow Cab     ATLANTA GA          6.18         138.40       87.5088
# 8       Yellow Cab     ATLANTA GA         39.60         704.30      494.2080
# ...            ...            ...           ...            ...           ...
# 359387  Yellow Cab  WASHINGTON DC         38.40         668.93      525.3120
# 359388  Yellow Cab  WASHINGTON DC          3.57          67.60       44.5536
# 359389  Yellow Cab  WASHINGTON DC         23.46         331.97      337.8240
# 359390  Yellow Cab  WASHINGTON DC         27.60         358.23      364.3200
# 359391  Yellow Cab  WASHINGTON DC         34.24         453.11      427.3152
#
#           Profit  Population   Users Payment_Mode  Gender  Age  \
# 1       281.2772      814885   24701         Cash    Male   28
# 2       194.6480      814885   24701         Card    Male   28
# 4       253.9808      814885   24701         Card    Male   27
# 5        50.8912      814885   24701         Cash    Male   27
# 8       210.0920      814885   24701         Card    Male   53
# ...          ...         ...     ...          ...     ...  ...
# 359387  143.6180      418859  127001         Cash  Female   29
# 359388   23.0464      418859  127001         Cash  Female   29
# 359389   -5.8540      418859  127001         Card  Female   29
# 359390   -6.0900      418859  127001         Cash  Female   29
# 359391   25.7948      418859  127001         Card  Female   29
#
#         Income (USD/Month)
# 1                    10813
# 2                    10813
# 4                     9237
# 5                     9237
# 8                    11242
# ...                    ...
# 359387                6829
# 359388                6829
# 359389                6829
# 359390                6829
# 359391                6829
#
# [274681 rows x 18 columns]

# %%
pdf=df[df['Company']=='Pink Cab']
pdf
# Out:
#         Transaction ID  Customer ID Date of Travel  Day  Month  Year  \
# 0             10000011        29290     2016-01-08    8      1  2016
# 3             10000012        27703     2016-01-06    6      1  2016
# 6             10395626        27703     2018-10-27   27     10  2018
# 7             10000013        28712     2016-01-02    2      1  2016
# 11            10000014        28020     2016-01-07    7      1  2016
# ...                ...          ...            ...  ...    ...   ...
# 359332        10200082        52425     2017-07-23   23      7  2017
# 359346        10262863        51257     2017-11-19   19     11  2017
# 359356        10417014        51257     2018-12-02    2     12  2018
# 359358        10197277        51510     2017-07-23   23      7  2017
# 359363        10267182        51510     2017-11-27   27     11  2017
#
#          Company           City  KM Travelled  Price Charged  Cost of Trip  \
# 0       Pink Cab     ATLANTA GA         30.45         370.95       313.635
# 3       Pink Cab     ATLANTA GA         28.62         358.52       334.854
# 6       Pink Cab     ATLANTA GA         13.39         167.03       141.934
# 7       Pink Cab     ATLANTA GA          9.04         125.20        97.632
# 11      Pink Cab     ATLANTA GA         33.17         377.40       351.602
# ...          ...            ...           ...            ...           ...
# 359332  Pink Cab  WASHINGTON DC         20.23         347.58       218.484
# 359346  Pink Cab  WASHINGTON DC          4.44          61.95        50.616
# 359356  Pink Cab  WASHINGTON DC         40.95         565.07       434.070
# 359358  Pink Cab  WASHINGTON DC         32.64         375.27       368.832
# 359363  Pink Cab  WASHINGTON DC         21.40         235.76       216.140
#
#          Profit  Population   Users Payment_Mode  Gender  Age  \
# 0        57.315      814885   24701         Card    Male   28
# 3        23.666      814885   24701         Card    Male   27
# 6        25.096      814885   24701         Card    Male   27
# 7        27.568      814885   24701         Cash    Male   53
# 11       25.798      814885   24701         Cash    Male   23
# ...         ...         ...     ...          ...     ...  ...
# 359332  129.096      418859  127001         Cash    Male   58
# 359346   11.334      418859  127001         Card    Male   39
# 359356  131.000      418859  127001         Card    Male   39
# 359358    6.438      418859  127001         Card  Female   18
# 359363   19.620      418859  127001         Card  Female   18
#
#         Income (USD/Month)
# 0                    10813
# 3                     9237
# 6                     9237
# 7                    11242
# 11                   23327
# ...                    ...
# 359332               10737
# 359346               15247
# 359356               15247
# 359358                6855
# 359363                6855
#
# [84711 rows x 18 columns]

# %% [markdown]
# ## EDA

# %% [markdown]
# #### Profit change per months over the years

# %%
sns.relplot(x="Month", y="Profit", hue="Year",data=ydf, kind='line',ci=None)
sns.relplot(x="Month", y="Profit", hue="Year",data=pdf, kind='line',ci=None)

# %%
sns.relplot(x="Month", y="Profit", hue="Year",data=pdf, kind='line',ci=None)

# %% [markdown]
# #### Customer Demographics based on City

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='City',data=ydf, hue='Gender')
plt.xticks(rotation=90)
plt.show()
plt.figure(figsize=(10, 6))
sns.countplot(x='City',data=pdf, hue='Gender')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.stripplot(x='City',y='Age',data=ydf)
plt.xticks(rotation=90)
plt.show()
plt.figure(figsize=(10, 6))
sns.stripplot(x='City',y='Age',data=pdf)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Which cab is more used in each City

# %% [markdown]
# #### Which Cab is more expensive on customers?

# %% [markdown]
# #### Which Cab costs more?

# %% [markdown]
# #### Hypothesis : Higher population leads to higher price charges?
