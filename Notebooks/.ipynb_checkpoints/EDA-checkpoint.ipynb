# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import datetime

# %%
cab=pd.read_csv('../data/Cab_Data.csv')
cab
# Out:
#         Transaction ID Date of Travel     Company           City  \
# 0             10000011     2016-01-08    Pink Cab     ATLANTA GA
# 1             10000012     2016-01-06    Pink Cab     ATLANTA GA
# 2             10000013     2016-01-02    Pink Cab     ATLANTA GA
# 3             10000014     2016-01-07    Pink Cab     ATLANTA GA
# 4             10000015     2016-01-03    Pink Cab     ATLANTA GA
# ...                ...            ...         ...            ...
# 359387        10440101     2018-01-08  Yellow Cab  WASHINGTON DC
# 359388        10440104     2018-01-04  Yellow Cab  WASHINGTON DC
# 359389        10440105     2018-01-05  Yellow Cab  WASHINGTON DC
# 359390        10440106     2018-01-05  Yellow Cab  WASHINGTON DC
# 359391        10440107     2018-01-02  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip
# 0              30.45         370.95      313.6350
# 1              28.62         358.52      334.8540
# ...

# %%
city=pd.read_csv('../data/City.csv')
city
# Out:
#                 City   Population      Users
# 0        NEW YORK NY   8,405,837    302,149
# 1         CHICAGO IL   1,955,130    164,468
# 2     LOS ANGELES CA   1,595,037    144,132
# 3           MIAMI FL   1,339,155     17,675
# 4     SILICON VALLEY   1,177,609     27,247
# 5      ORANGE COUNTY   1,030,185     12,994
# 6       SAN DIEGO CA     959,307     69,995
# 7         PHOENIX AZ     943,999      6,133
# 8          DALLAS TX     942,908     22,157
# 9         ATLANTA GA     814,885     24,701
# 10         DENVER CO     754,233     12,421
# 11         AUSTIN TX     698,371     14,978
# 12        SEATTLE WA     671,238     25,063
# 13         TUCSON AZ     631,442      5,712
# 14  SAN FRANCISCO CA     629,591    213,609
# 15     SACRAMENTO CA     545,776      7,044
# 16     PITTSBURGH PA     542,085      3,643
# 17     WASHINGTON DC     418,859    127,001
# 18      NASHVILLE TN     327,225      9,270
# 19         BOSTON MA     248,968     80,021

# %%
cust=pd.read_csv('../data/Customer_ID.csv')
cust
# Out:
#        Customer ID  Gender  Age  Income (USD/Month)
# 0            29290    Male   28               10813
# 1            27703    Male   27                9237
# 2            28712    Male   53               11242
# 3            28020    Male   23               23327
# 4            27182    Male   33                8536
# ...            ...     ...  ...                 ...
# 49166        12490    Male   33               18713
# 49167        14971    Male   30               15346
# 49168        41414    Male   38                3960
# 49169        41677    Male   23               19454
# 49170        39761  Female   32               10128
#
# [49171 rows x 4 columns]

# %%
trans=pd.read_csv('../data/Transaction_ID.csv')
trans
# Out:
#         Transaction ID  Customer ID Payment_Mode
# 0             10000011        29290         Card
# 1             10000012        27703         Card
# 2             10000013        28712         Cash
# 3             10000014        28020         Cash
# 4             10000015        27182         Card
# ...                ...          ...          ...
# 440093        10440104        53286         Cash
# 440094        10440105        52265         Cash
# 440095        10440106        52175         Card
# 440096        10440107        52917         Card
# 440097        10440108        51587         Card
#
# [440098 rows x 3 columns]

# %%
df1=pd.merge(cab, city, on='City')
df1
# Out:
#         Transaction ID Date of Travel     Company           City  \
# 0             10000011     2016-01-08    Pink Cab     ATLANTA GA
# 1             10000012     2016-01-06    Pink Cab     ATLANTA GA
# 2             10000013     2016-01-02    Pink Cab     ATLANTA GA
# 3             10000014     2016-01-07    Pink Cab     ATLANTA GA
# 4             10000015     2016-01-03    Pink Cab     ATLANTA GA
# ...                ...            ...         ...            ...
# 359387        10440101     2018-01-08  Yellow Cab  WASHINGTON DC
# 359388        10440104     2018-01-04  Yellow Cab  WASHINGTON DC
# 359389        10440105     2018-01-05  Yellow Cab  WASHINGTON DC
# 359390        10440106     2018-01-05  Yellow Cab  WASHINGTON DC
# 359391        10440107     2018-01-02  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip Population      Users
# 0              30.45         370.95      313.6350   814,885     24,701
# ...

# %%
df2=pd.merge(df1, trans, on='Transaction ID')
df2
# Out:
#         Transaction ID Date of Travel     Company           City  \
# 0             10000011     2016-01-08    Pink Cab     ATLANTA GA
# 1             10000012     2016-01-06    Pink Cab     ATLANTA GA
# 2             10000013     2016-01-02    Pink Cab     ATLANTA GA
# 3             10000014     2016-01-07    Pink Cab     ATLANTA GA
# 4             10000015     2016-01-03    Pink Cab     ATLANTA GA
# ...                ...            ...         ...            ...
# 359387        10440101     2018-01-08  Yellow Cab  WASHINGTON DC
# 359388        10440104     2018-01-04  Yellow Cab  WASHINGTON DC
# 359389        10440105     2018-01-05  Yellow Cab  WASHINGTON DC
# 359390        10440106     2018-01-05  Yellow Cab  WASHINGTON DC
# 359391        10440107     2018-01-02  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip Population      Users  \
# 0              30.45         370.95      313.6350   814,885     24,701
# ...

# %%
df=pd.merge(df2, cust, on='Customer ID')
df
# Out:
#         Transaction ID Date of Travel     Company           City  \
# 0             10000011     2016-01-08    Pink Cab     ATLANTA GA
# 1             10351127     2018-07-21  Yellow Cab     ATLANTA GA
# 2             10412921     2018-11-23  Yellow Cab     ATLANTA GA
# 3             10000012     2016-01-06    Pink Cab     ATLANTA GA
# 4             10320494     2018-04-21  Yellow Cab     ATLANTA GA
# ...                ...            ...         ...            ...
# 359387        10307228     2018-03-03  Yellow Cab  WASHINGTON DC
# 359388        10319775     2018-04-13  Yellow Cab  WASHINGTON DC
# 359389        10347676     2018-07-06  Yellow Cab  WASHINGTON DC
# 359390        10358624     2018-08-02  Yellow Cab  WASHINGTON DC
# 359391        10370709     2018-08-30  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip Population      Users  \
# 0              30.45         370.95      313.6350   814,885     24,701
# ...

# %% [markdown]
# ## Cleaning

# %% [markdown]
# ### Check NAs

# %%
df.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# ### Converting Users and Population columns into integers

# %%
df['Users']=df['Users'].str.replace(',',"").astype(int)
df['Population']=df['Population'].str.replace(',',"").astype(int)

# %% [markdown]
# ### Converting Date of Travel column into a date column

# %%
df['Date of Travel']=pd.to_datetime(df['Date of Travel'])

# %% [markdown]
# ### Extracting Days, Months, and Years out of Date of travel column to new columns

# %%
df['Day'] = df['Date of Travel'].dt.day
df['Month'] = df['Date of Travel'].dt.month
df['Year'] = df['Date of Travel'].dt.year

# %% [markdown]
# ### Calculating Profit by subtracting costs from revenue

# %%
df['Profit']=df['Price Charged']-df['Cost of Trip']

# %% [markdown]
# ### Convert Transaction ID and Customer ID columns into strings

# %%
df['Transaction ID']=df['Transaction ID'].astype(str)
df['Customer ID']=df['Customer ID'].astype(str)

# %% [markdown]
# ### Check Columns Datatypes

# %%
df.dtypes
# Out:
# Transaction ID                object
# Date of Travel        datetime64[ns]
# Company                       object
# City                          object
# KM Travelled                 float64
# Price Charged                float64
# Cost of Trip                 float64
# Population                     int32
# Users                          int32
# Customer ID                   object
# Payment_Mode                  object
# Gender                        object
# Age                            int64
# Income (USD/Month)             int64
# Day                            int64
# Month                          int64
# Year                           int64
# Profit                       float64
# dtype: object

# %% [markdown]
# ### Check column names and see how it is arranged

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Date of Travel', 'Company', 'City', 'KM Travelled',
#        'Price Charged', 'Cost of Trip', 'Population', 'Users', 'Customer ID',
#        'Payment_Mode', 'Gender', 'Age', 'Income (USD/Month)', 'Day', 'Month',
#        'Year', 'Profit'],
#       dtype='object')

# %% [markdown]
# ### Rearrange columns

# %%
reindex=['Transaction ID',
         'Customer ID',
         'Date of Travel',
         'Day',
         'Month',
         'Year',
         'Company',
         'City',
         'KM Travelled',
         'Price Charged',
         'Cost of Trip',
         'Profit',
         'Population',
         'Users',
         'Payment_Mode',
         'Gender',
         'Age',
         'Income (USD/Month)',
]
df=df.reindex(columns=reindex)

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Check dataset statistical information

# %%
# Continuous Data
df.describe()
# Out:
#                  Day          Month           Year   KM Travelled  \
# count  359392.000000  359392.000000  359392.000000  359392.000000
# mean       15.628447       7.500434    2017.045199      22.567254
# std         8.827151       3.445095       0.800239      12.233526
# min         1.000000       1.000000    2016.000000       1.900000
# 25%         8.000000       5.000000    2016.000000      12.000000
# 50%        16.000000       8.000000    2017.000000      22.440000
# 75%        23.000000      10.000000    2018.000000      32.960000
# max        31.000000      12.000000    2018.000000      48.000000
#
#        Price Charged   Cost of Trip         Profit    Population  \
# count  359392.000000  359392.000000  359392.000000  3.593920e+05
# mean      423.443311     286.190113     137.253198  3.132198e+06
# std       274.378911     157.993661     160.311840  3.315194e+06
# min        15.600000      19.000000    -220.060000  2.489680e+05
# ...

# %%
# Catigorical Data
df.describe(exclude='number')
# Out:
# <ipython-input-19-b4c5c6db7380>:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(exclude='number')
#        Transaction ID Customer ID       Date of Travel     Company  \
# count          359392      359392               359392      359392
# unique         359392       46148                 1095           2
# top          10347139         494  2018-01-05 00:00:00  Yellow Cab
# freq                1          54                 2022      274681
# first             NaN         NaN  2016-01-02 00:00:00         NaN
# last              NaN         NaN  2018-12-31 00:00:00         NaN
#
#                City Payment_Mode  Gender
# count        359392       359392  359392
# unique           19            2       2
# top     NEW YORK NY         Card    Male
# ...

# %% [markdown]
# ## Insights

# %% [markdown]
# #### Profit change per months over the years

# %%
a=sns.relplot(x="Month", y="Profit", hue="Year",data=df, kind='line',ci=None, col='Company')
a.fig.suptitle('Average profit change per months over the years', fontsize=12)
a.fig.subplots_adjust(top=0.8)
plt.show()
#plt.savefig('../Photos/ProfitChange.png')

# %% [markdown]
# #### Customer Retention

# %%
fig, axes = plt.subplots(1,2, sharey=True, figsize=(14,5))
fig.suptitle('Customer Retention', fontsize=14)
df[df['Company']=='Yellow Cab']['Customer ID'].value_counts().plot(ax=axes[1])
axes[1].set_title('Yellow Cab')
axes[1].set_xlabel('Customer ID')
axes[0].set_ylabel('Number of transactions')
df[df['Company']=='Pink Cab']['Customer ID'].value_counts().plot(ax=axes[0])
axes[0].set_title('Pink Cab')
axes[0].set_xlabel('Customer ID')
plt.show()
#plt.savefig('../Photos/CustomerRetention.png')

# %% [markdown]
# #### Which cab is more used in each City

# %%
b=sns.catplot(x='City',data=df, hue='Gender',kind="count",col='Company').set_xticklabels(rotation=90)
b.fig.suptitle('Which cab is more used in each City', fontsize=12)
b.fig.subplots_adjust(top=0.8)
plt.show()
#plt.savefig('../Photos/CabUsed.png')

# %% [markdown]
# #### Customer Demographics based on City

# %%
c=sns.relplot(x='City',y='Age', hue='Gender',data=df,kind='line',ci=None, col='Company').set_xticklabels(rotation=90)
c.fig.suptitle('Average customer ages distributed by cities', fontsize=12)
c.fig.subplots_adjust(top=0.8)
plt.show()
#plt.savefig('../Photos/CustomerDemog1.png')

# %%
d=sns.relplot(x='City',y='Income (USD/Month)', hue='Gender',data=df,kind='line',ci=None, col='Company').set_xticklabels(rotation=90)
d.fig.suptitle('Average customer income distributed by cities', fontsize=12)
d.fig.subplots_adjust(top=0.8)
plt.show()
#plt.savefig('../Photos/CustomerDemog2.png')

# %% [markdown]
# #### Which Cab is more expensive on customers?

# %%
e=sns.relplot(x='KM Travelled',y='Price Charged',data=df,col='Company')
e.fig.suptitle('Which Cab is more expensive on customers?', fontsize=12)
e.fig.subplots_adjust(top=0.8)
plt.show()
#plt.savefig('../Photos/ExpCab.png')

# %% [markdown]
# #### Which Cab costs more?

# %%
f=sns.relplot(y='Cost of Trip',x='Month',col='Company', data=df, kind='line', hue='Year', ci=None)
f.fig.suptitle('Which Cab costs more?', fontsize=12)
f.fig.subplots_adjust(top=0.8)
plt.show()
#plt.savefig('../Photos/CostCab.png')

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ### Results

# %% [markdown]
# Yellow cab generated more revenue than Pink Cab considering the number of transactions for each.
#
# Both cabs generate less in year 2018.
#
# In Yellow Cab, we can see a noticeable peak in May and June in all years, which indicate and increased demand.
#
# In Pink Cab, we can see there is loss in profit from January to May. Then the profit keeps increasing.
#
# --------------------
#
# There highest number of transactions by a single customer in Yellow Cab is more than 40 while in Pink Cab is less than 20 transactions.
#
# ---------------------
# Males use the cabs more than women in all cities.
#
# Yellow Cab is popular in New York, Chicago, Washington DC, Los Angeles and Boston respectively.
#
# Pink Cab is popular in Los Angeles, New York, San Diego, Chicago and Boston respectively.
#
# Yellow cab is used approximately 5X more than Pink Cab by both genders.
#
# ---------------------
#
# The minimum – maximum ages of customers are (18-65).
#
# The average age of customers of both cabs is (34-37).
#
# ---------------------
#
# The minimum – maximum Income of customers are (2000-35000).
#
# The average income of customers of both cabs is (34-37).
#
# ---------------------
#
# There is a positive relationship between KM travelled and Price charged.
#
# Yellow Cab has generated higher charges at 50KM than Pink Cab.
#
# ---------------------
#
# Average spending of Yellow Cab is between 290 to 300.
#
# Average spending of Pink Cab is between 240 to 260.

# %% [markdown]
# ### Reccomendations

# %% [markdown]
# Based on results, despite the high spent charges, it is recommended to invest in Yellow Cab since it has 5X more Customers than Pink Cab and it generates almost double profit than Pink Cab. In addition, it operates on high population cities with high income customers.
